# %%
import matplotlib.pyplot as plt
import sys
import os

sys.path.append(os.path.abspath("../src"))

from utils.mpiigaze_dataset import *

# %%
dataset = MPIIGazeDataset('../dataset/MPIIGaze/Data/Original')

# %%
df_screen = dataset.get_screen_sizes()

# %%
df = dataset.to_dataframe()

# %%
df
# Out:
#                                                  img_path  gaze_x  gaze_y
# 0       ../dataset/MPIIGaze/Data/Original/p00/day01/00...   854.0   270.0
# 1       ../dataset/MPIIGaze/Data/Original/p00/day01/00...   806.0   630.0
# 2       ../dataset/MPIIGaze/Data/Original/p00/day01/00...   948.0   467.0
# 3       ../dataset/MPIIGaze/Data/Original/p00/day01/00...   389.0   166.0
# 4       ../dataset/MPIIGaze/Data/Original/p00/day01/00...   476.0   758.0
# ...                                                   ...     ...     ...
# 213653  ../dataset/MPIIGaze/Data/Original/p14/day07/01...   730.0   138.0
# 213654  ../dataset/MPIIGaze/Data/Original/p14/day07/01...   963.0   803.0
# 213655  ../dataset/MPIIGaze/Data/Original/p14/day07/01...  1339.0   801.0
# 213656  ../dataset/MPIIGaze/Data/Original/p14/day07/01...  1362.0    92.0
# 213657  ../dataset/MPIIGaze/Data/Original/p14/day07/02...   344.0   883.0
#
# [213658 rows x 3 columns]

# %%
len(dataset)
# Out:
# 213658

# %%
df_screen
# Out:
#    subject  width_pixel  height_pixel  width_mm  height_mm
# 0      p00         1280           800  286.4708   179.0442
# 1      p01         1440           900  286.4708   179.0442
# 2      p02         1280           800  286.4708   179.0442
# 3      p03         1440           900  286.4708   179.0442
# 4      p04         1280           800  286.4708   179.0442
# 5      p05         1440           900  286.4708   179.0442
# 6      p06         1680          1050  331.7030   207.3144
# 7      p07         1440           900  286.4708   179.0442
# 8      p08         1440           900  286.4708   179.0442
# 9      p09         1440           900  286.4708   179.0442
# 10     p10         1440           900  286.4708   179.0442
# 11     p11         1280           800  286.4708   179.0442
# 12     p12         1280           800  286.4708   179.0442
# 13     p13         1280           800  286.4708   179.0442
# 14     p14         1440           900  286.4708   179.0442

# %%
dataset.plot_screen_size_histogram()
